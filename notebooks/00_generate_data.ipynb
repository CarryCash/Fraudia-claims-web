# %% [markdown]
# # 00 – Generación de datos sintéticos
# Este notebook ejecuta el script `scripts/generate_synthetic.py` para crear los CSV de ejemplo en la carpeta `data/raw/`.
# Ejecuta la celda abajo para generar los datos.

# %%
# !python scripts/generate_synthetic.py
# Out:
# python: can't open file 'c:\\Users\\USER\\Downloads\\fraudia-claims\\notebooks\\scripts\\generate_synthetic.py': [Errno 2] No such file or directory
